# %% [markdown]
# # Libreria para cargar imagenes

# %%
from IPython.display import display, Image

# %% [markdown]
# # **Solemne** **1** **Mineria** **de** **Datos**

# %% [markdown]
# **Analisis de vacunacion y su correlacion con la lejania de la Capital y Marco Temporal efectos secundarios vacunas**
#
# Informe de Solemne.
#
# Luis Gonzalez.

# %% [markdown]
# # Proposito

# %% [markdown]
# Para el dataset escogido "covid19 vaccination search_insights" se plantea ver  si existe una relación directa entre la tasa de vacunación y la población existente en 5 regiones de Australia, además si existen una correlación entre la distancia a la capital y a su centro portuario mas grande y la tasa de vacunación de cada región. Además de esto, se planteó ver si los efectos secundarios de las vacunas empiezan inmediatamente Luego de la vacunación o posee cierto retraso temporal significativo.

# %% [markdown]
# Todo esto con el proposito de realizar un analisis de dato exaustivo usando las herramientas entregadas por SQL, GoogleCloud y Bigquery

# %% [markdown]
# #  Graficos de Vacunacion

# %% [markdown]
# Primeramente se Grafico 5 regiones diferentes de Australia, en funcion de la tasa de vacunacion y la fecha de esta misma , con el objetivo de visualizar las amplitudes de vacunacion y sus ventanas temporales.
# Las regiones escogidas fueron las siguientes:
# - South Australia
# - South New Wales
# - Western Australia
# - Queensland
# - Victoria

# %% [markdown]
# Llegando a los siguientes Graficos :

# %%
imagen = 'Vac WA.png'
ancho = 700
alto = 400
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 1 :** Vacunacion Western Australia

# %%
imagen = 'Vac NSW.png'
ancho = 700
alto = 400
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 2:** Vacunacion en New South Wales

# %%
imagen = 'Vac SA.png'
ancho = 700
alto = 400
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 3:** Vacunacion en South Australia

# %%
imagen = 'Vac Q.png'
ancho = 700
alto = 400
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 4:** Vacunacion en Queensland

# %%
imagen = 'Vac V.png'
ancho = 700
alto = 400
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 5:** Vacunacion en Victoria

# %% [markdown]
# **Comentario y Observaciones** : Podemos hacer observaciones iniciales accerca de los graficos mostrados.
#
# - Western Australia: Se puede observar una subida bastante lenta de la tasa de vacunacion, con leves picos a partir del 07/06/2021, pero no es hasta 27/12/2021 que la tasa de vacunacion crese de manera subita alcanzando el peak de 240 para luego a  mediados de enero de 2022 bajar abruptamente hasta finales del mismo mes en donde de ahi en adelante ira descendiendo de forma gradual y lenta hasta llegar a aproximadamente 0 en 2023.
# - New South Wales: En el grafico asociado a esta region, se puede apreciar una subida muy pronta y abrupta de la tasa de vacunacion a partir de mayo/2021 ,en donde se mantiene por aproximadamente 5 meses llegando a su peak con llegando al rededor de 170 para luego caer de forma rapida hasta aproximadamente marzo de 2022 en donde se reduce de un decrecimiento rapido a uno mas graual hasta llegar a 0 aproximadamente en el año 2023, con una leve subida en junio de 2022.
# - South Australia:  la tasa de vacunacion posee un crecimiento gradual hasta abril de 2021 en donde crece de forma rapida hasta sobrepasar las 100 en agosto de 2021 y mantenerse con variaciones leves llegando como maximo 120 , hasta principios de 2022 en donde decrece forma abrupta hasta llegar a marzo de 2022 en donde decae de forma gradual tendiendo a 0.
# - Queenslad:Podemos observar como posee una subida progresiva desde Enero del 2021 llegando hasta alredores de Junio/Agosto del mismo año, en donde crece de manera abruta para luego descender y volver a subir, hasta llegar aun peak maximo alredor de enero de 2022, para luego bajar progresivamente.
# - Victoria: Finalmente para la region de Victoria, en donde empieza con un crecimiento rapido pero leve a inicios de 2021 para luego desender y mantenerse estable hasta mayo de ese mismo año, en donde empieza crecer llegando a su peak maximo por octubre de 2021 y decendiendo gradualmente hasta enero de 2022 en donde hay una alza para luego bajar y tender a 0 por la primera mitad de ese mismo año con una leve alza en julio de 2022 para volver a decender tendiendo a 0.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Aqui colocare los grafico alineados en escala Temporal y superpuestos, para asi poder observar de mejor manera, la diferencia temporal

# %%
imagen = 'CompAll.png'
ancho = 700
alto = 950
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 6** : Graficos de Vacunacion

# %% [markdown]
# **Comentario y Observaciones**:  Podemos ver que existe una clara Diferencia en el apartado temporal y la subida rapida de las tasas de vacunaciones , en donde se puede apreciar que la subida mas temprana fue en South australia y luego en New South Wales, a pesar de que que la subida en New South Wales , fue mas abrupta y rapida,,mientras que la mas tardia es Western Austrlia.

# %% [markdown]
# # Graficos Cantidad de Vacunados

# %% [markdown]
# En esta parte, veremos lo graficos y comparacion entre la cantidad de personas vacunadas.

# %%
imagen = 'Ciudades Buena.png'
ancho = 700
alto = 400
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 7:** Histogrma de Vacunacion

# %%
imagen = 'Pastel.png'
ancho = 700
alto = 600
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 8:** Grafico tipo Pastel , en funcion del porcentaje total de vacunados

# %% [markdown]
# **Comentario y Observaciones:** Podemos evidenciar como se ve una clara supremacia e torno a New South Wales seguida por South Australia

# %% [markdown]
# # Graficos de Efectos Secundarios

# %% [markdown]
# En esta parte se revisaron y compararon la tasa de efectos secundarios y la tasa de vacunacion con el objetivo de ver si existe un retraso temporal en los efectos secundarios y la vacunacion, se presentaras 2 Regiones diferentes para estiamar si se logra apreciar un retraso temporal significativo

# %%
imagen = 'Efectos Secundarios1.png'
ancho = 700
alto = 400
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 9:** Comparacion efectos secundarios y vacunacion (New South Wales)

# %%
imagen = 'Efectos Secundarios3.png'
ancho = 700
alto = 400
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 10:** Comparacion efectos secundarios y vacunacion (Queensland)

# %% [markdown]
# **Comentarios y Observaciones** Podemos darnos cuentas en la figura 9 que la forma de ambos graficos es sumamente parecida,variando unicamente su amplitud y ciertos peaks.
#
# Ademas la ventanda temporal de ambos graficos en relativamente la misma , en donde a lo mas, se evidencia a lo mucho una leve translacion de a lo mas unos cuantos dias, ademas de variar en ciertos peaks, lo cual indicaria que existe una diferencia temporal.
#
# Lo mismo Aplica a la figura 10, variando unicamente la amplitud y ciertos peaks, demostrando que existe un periodo tardio en la aparicion de efectos secundarios.

# %% [markdown]
# Por  ultimo se estudio,el porcentaje de efectos secundarios en base al total de los vacunados.

# %%
imagen = 'HisttAr.png'
ancho = 700
alto = 400
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 11:** Podemos evidenciar que la zona con mas efectos secundarios en comparacion con la cantidad de vacundos es New South Wales, mientras la que posee menor porcentaje es Victoria

# %% [markdown]
# ~ Nota: el nombre de New South Wales fue alterado en paint por problemas de fuerza mayor con el notebook en el cual se realizo el codigo

# %% [markdown]
# **Comentarios y Observaciones:** Podemos observar como el mayor porcentaje de efectos secundarios en funcion de la cantidad de vacunados en la propia region fue New South Wales, mientras el menor fue Victoria

# %% [markdown]
# # Analisis de los Datos y  Concluciones

# %% [markdown]
# **Tasa de Vacunacion por Region y sus Fechas**: Usando los graficos obtenidos en las Figuras de la 1 a la 6, podemos evidencias una clara diferencia temporal entre ciertas regiones, como mencionamos en el apartado de "Comentarios y Observaciones" La region que empezo mas temprano su plan de vacunacion fue South Australia y mientras que la mas tardia fue Western Australia, por lo tanto, se planteo la posibilidad de que a mayor cercania de la capital, mas temprano empezaba la vacunacion efectiva y masiva.
# **Observando el mapa de Australia:**

# %%
imagen = '197252683-australia-mapa-político-coloreado-con-la-capital-canberra-y-estados-y-territorios-administrativos.jpg'
ancho = 700
alto = 600
display(Image(filename=imagen, width=ancho, height=alto))

# %% [markdown]
# **Figura 12**: Mapa de Australia

# %% [markdown]
# En donde podemos darnos cuenta, que Canberra , lse encuentra en la region de New South Wales y las 3 regiones limitrofes a esta son Victoria , South Australia y Queensland.

# %% [markdown]
# Aqui se puede encontrar un relacion entre los datos, ya que en orden de alza rapida en la tasa de vacunaciones , seria:
# - South Australia
# - New South Wales
# - Victoria
# - Queenland
# - Western Australia

# %% [markdown]
# Pero a pesar de estar relacionado de forma estrecha, el hecho de que South Australia , posea un inico mas anticipado que New South Wales dice que la tendencia encontrada, no es del todo cierta.

# %% [markdown]
# A pesar de esto, si tenemos una clara idea, la zona media este de australia fue la mas vacunada.

# %% [markdown]
# En base a la investigacion realizada en el analisis de datos, Conociendo los mayores puertos de carga de Australia , siendo los Siguientes:
#
# - Sydney (New South Wales)
# - Melbourne (Victoria)
# - Adelaide (South Australia)
# - Brisbane (Queensland)
#
# Todos estos estando geograficamente cercanos al sureste Austrliano
# y conociendo los mayores aeropuertos cargueros de australia
# siendo:
#
# - Sidney
# - Melbourne
#
# se logra evidenciar la posible causa de que la zona sureste haya comenzado su plan de vacunacion y sus peaks de esta misma mucho antes que la zona norte u oeste.

# %% [markdown]
# **Comparacion entre la poblacion vacunada y la poblacion total en cada region:**

# %% [markdown]
# Podemos ver como la zona con mayor vacunados es New South Australia, Seguido por South Australia  luego Western australia , para finalmente tener a Queensland y Victoria

# %% [markdown]
# Y conociendo la  densidad de poblacion de cada region:

# %% [markdown]
# - New South Wales --> 9,12 hab/km2
# - South Australia --> 1,84 hab/km2
# - Western Australia --> 1 hab/km2
# - Queensland --> 2,61 hab/km2
# - victoria --> 24.51 hab/
#
# Datos recabados en 2022
#
# Fuente: https://inaturalist.mma.gob.cl/

# %% [markdown]
# Podemos sacar 2 tipos de concluciones en base a los datos tomados, primeramente se logra apreciar como la zona sureste empezo su plan de vacunacion antes que la zona oeste, considerando que es la zona con mayor densidad poblacion de Australia.

# %% [markdown]
# Ademas de que no existe una correlacion directa entre la cantidad de vacunados y la densidad poblacional de una region, ya sea de forma directa o de forma inversamente proporcional.

# %% [markdown]
# **Efectos Secundarios**

# %% [markdown]
# Podemos evidenciar viendo las figuras 9 y 10, que en un marco temporal, no existe una gran diferencia entre la aparicion de efectos secundarios y la vacunacion, ya que ambos datos poseen un comportamiento similirar, variando unicamente en peaks puntales los cuales hacen un indicio de que si puede haber un leve retraso en la aparicion, pero nada mas alla de un mes por lo visto.

# %% [markdown]
# Pero visto de una manera mas general, ambas dataset poseen comportamientos similares. por consiguiente no se aprecia un peak de efectos secundarios luego del descenso de la vacunacion, lo que implica que no aparecen luego de un par de meses.

# %% [markdown]
# Por ultimo, podemos ver en la figura 11, como el porcentaje de efectos secundarios varian de region en region, por lo tanto, pueden existir 2 posibles razones, el tipo de vacuna que se uso mayoritariamente o el tipo de poblacion de cada region.

# %% [markdown]
# Como acotacion:
#
# A pesar de seguir siendo objeto de discucion, se barajea la posibilidad que a mayor edad una persona es mas suceptible a los efectos secundarios de un farmaco, esto incluye las vacunas,
# Por consiguiente, los estados con mas casos de efectos secundarios podrian deberse a una mayor cantidad de personas mayores.

# %% [markdown]
# No se logro obtener ni datasets ni informacion de distribucion demografica en Australia por consiguiente lo dicho anteriormente sera unicamente como un comentario
